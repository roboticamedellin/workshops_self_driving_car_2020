# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = plt.imread('image.jpg')
plt.imshow(img)

# %%
url = "http://10.42.0.1:8080/stream/video.jpeg"
cap = cv2.VideoCapture(url)
ret, frame = cap.read()
if ret:
#     plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    plt.imshow(frame)
    plt.imwrite('image.jpg',frame)
cap.release()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-440bedeca9af> in <module>
#       5 #     plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
#       6     plt.imshow(frame)
# ----> 7     plt.imwrite('image.jpg',frame)
#       8 cap.release()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'imwrite'
